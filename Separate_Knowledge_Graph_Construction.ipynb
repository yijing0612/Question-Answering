# %% [markdown]
# **This notebook is to construct knowledge graph from separate KB file, which means each graph only contained the information of that particular document, and all graphs are saved to HTML format.**
#
# **The output from this notebook is for visualization in the report.**

# %%
from pyvis.network import Network
import networkx as nx
import os
import pickle

# %% [markdown]
# ### Load KB file

# %%
def load_kb(filename):
    res = None
    with open(filename, "rb") as f:
        res = pickle.load(f)
    return res

# %%
#declare the class KB
import wikipedia

class KB():
    def __init__(self):
        self.entities = {} # { entity_title: {...} }
        self.relations = [] # [ head: entity_title, type: ..., tail: entity_title,
          # meta: { article_url: { spans: [...] } } ]
        self.sources = {} # { article_url: {...} }

    def merge_with_kb(self, kb2):
        for r in kb2.relations:
            article_url = list(r["meta"].keys())[0]
            source_data = kb2.sources[article_url]
            self.add_relation(r, source_data["article_title"],
                              source_data["article_publish_date"])

    def are_relations_equal(self, r1, r2):
        return all(r1[attr] == r2[attr] for attr in ["head", "type", "tail"])

    def exists_relation(self, r1):
        return any(self.are_relations_equal(r1, r2) for r2 in self.relations)

    def merge_relations(self, r2):
        r1 = [r for r in self.relations
              if self.are_relations_equal(r2, r)][0]

        # if different article
        article_url = list(r2["meta"].keys())[0]
        if article_url not in r1["meta"]:
            r1["meta"][article_url] = r2["meta"][article_url]

        # if existing article
        else:
            spans_to_add = [span for span in r2["meta"][article_url]["spans"]
                            if span not in r1["meta"][article_url]["spans"]]
            r1["meta"][article_url]["spans"] += spans_to_add

    def get_wikipedia_data(self, candidate_entity):
        try:
          #page = wikipedia.page(candidate_entity, auto_suggest=False)
          page = wikipedia.page(candidate_entity, auto_suggest=False)
            
          entity_data = {
            "title": page.title,
            "url": page.url,
            "summary": page.summary
          }
          return entity_data
        except:
          entity_data = {
            "title": candidate_entity+"*",
            "url": "",
            "summary": ""
          }
          return entity_data
          #return None

    def add_entity(self, e):
        self.entities[e["title"]] = {k:v for k,v in e.items() if k != "title"}

    def add_relation(self, r, article_title, article_publish_date):
        # check on wikipedia
        candidate_entities = [r["head"], r["tail"]]
        entities = [self.get_wikipedia_data(ent) for ent in candidate_entities]

        # if one entity does not exist, stop
        if any(ent is None for ent in entities):
            return

        # manage new entities
        for e in entities:
            self.add_entity(e)

        # rename relation entities with their wikipedia titles
        r["head"] = entities[0]["title"]
        r["tail"] = entities[1]["title"]

        # add source if not in kb
        article_url = list(r["meta"].keys())[0]
        if article_url not in self.sources:
            self.sources[article_url] = {
                "article_title": article_title,
                "article_publish_date": article_publish_date
            }

        # manage new relation
        if not self.exists_relation(r):
            self.relations.append(r)
        else:
            self.merge_relations(r)

    def print(self):
        print("Entities:")
        for e in self.entities.items():
            print(f"  {e}")
        print("Relations:")
        for r in self.relations:
            print(f"  {r}")
        print("Sources:")
        for s in self.sources.items():
            print(f"  {s}")

# %% [markdown]
# ### Construct knowledge graph to HTML format

# %%
def contruct_graph(kb, output_file):
    """
    Visualize a knowledge graph using the pyvis library.

    Parameters:
        kb (KB): The knowledge base containing entities and relations.
        output_file (str): The name of the HTML file to save the visualization.

    Returns:
        None
    """
    # Create a directed graph
    net = Network(
        directed=True,
        width="1200px",
        height="1000px",
        bgcolor="#FFFFFF",
        notebook=True,
    )

    # Nodes
    color_entity = "#00FF00"
    for e in kb.entities:
        net.add_node(e)
        print("add note",e)

    # Edges
    for r in kb.relations:
        net.add_edge(r["head"], r["tail"], title=r["type"], label=r["type"])
        print("add relation",r["head"]," ",r["tail"])

    # Graph settings
    net.repulsion(
        node_distance=230,
        damping=0.01
    )
    net.set_edge_smooth('dynamic')

    # Save the graph to an HTML file
    net.show(output_file)

# %% [markdown]
# ### Run the function on all KB files

# %%
def process_all_kb_files(kb_folder, graph_folder):
    """
    Process all KB files in the specified folder and generate knowledge graphs.

    Parameters:
        kb_folder (str): The folder containing KB files.
        graph_folder (str): The folder to save the generated knowledge graphs.
    """
    # Ensure the output graph folder exists
    os.makedirs(graph_folder, exist_ok=True)

    # Iterate over KB files in the folder
    for kb_file in os.listdir(kb_folder):
        if kb_file.endswith(".kb"):
            kb_path = os.path.join(kb_folder, kb_file)
            graph_file = os.path.splitext(kb_file)[0] + ".html"
            graph_path = os.path.join(graph_folder, graph_file)

            # Load KB
            print(f"Processing KB file: {kb_path}")
            kb = load_kb(kb_path)

            # Generate and save knowledge graph
            print(f"Generating knowledge graph for: {graph_file}")
            contruct_graph(kb, output_file=graph_path)

            print(f"Knowledge graph saved at: {graph_path}")
            print("=" * 50)

# %%
kb_folder = 'separate_kb_folder/'
graph_folder = 'separate_graph_folder/'

# %%
process_all_kb_files(kb_folder, graph_folder)
# Out:
# Processing KB file: separate_kb_folder/Raymond Kurzweil 1 CoreNLP.kb
# Generating knowledge graph for: Raymond Kurzweil 1 CoreNLP.html
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# add note Ray Kurzweil
# add note February 12, 1948*
# add note Computer scientist
# add note National Medal of Technology and Innovation
# add note United States
# add note Lemelson–MIT Prize
# add note National Inventors Hall of Fame
# add note Thomas Edison
# add note rightful heir*
# add relation Ray Kurzweil   February 12, 1948*
# add relation Ray Kurzweil   Computer scientist
# add relation Ray Kurzweil   National Medal of Technology and Innovation
# add relation National Medal of Technology and Innovation   United States
# add relation Ray Kurzweil   Lemelson–MIT Prize
# add relation Ray Kurzweil   National Inventors Hall of Fame
# add relation National Inventors Hall of Fame   Ray Kurzweil
# add relation National Inventors Hall of Fame   United States
# add relation Thomas Edison   rightful heir*
# Knowledge graph saved at: separate_graph_folder/Raymond Kurzweil 1 CoreNLP.html
# ==================================================
# Processing KB file: separate_kb_folder/Raymond Kurzweil 1.kb
# Generating knowledge graph for: Raymond Kurzweil 1.html
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# add note Ray Kurzweil
# add note February 12, 1948*
# add note Computer scientist
# add note National Medal of Technology and Innovation
# add note United States
# add note Lemelson–MIT Prize
# add note National Inventors Hall of Fame
# add relation Ray Kurzweil   February 12, 1948*
# add relation Ray Kurzweil   Computer scientist
# add relation Ray Kurzweil   National Medal of Technology and Innovation
# add relation National Medal of Technology and Innovation   United States
# add relation Ray Kurzweil   Lemelson–MIT Prize
# add relation Ray Kurzweil   National Inventors Hall of Fame
# add relation National Inventors Hall of Fame   Ray Kurzweil
# add relation National Inventors Hall of Fame   United States
# Knowledge graph saved at: separate_graph_folder/Raymond Kurzweil 1.html
# ==================================================
# Processing KB file: separate_kb_folder/Raymond Kurzweil 10 NLP.kb
# Generating knowledge graph for: Raymond Kurzweil 10 NLP.html
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# add note Kurzweil Reading Machine*
# add note Ray Kurzweil
# add note Inventor of the Year*
# add note Massachusetts Institute of Technology
# add note Berklee College of Music
# add note Dickson Prize
# add note National Medal of Technology and Innovation
# add note Academy of Achievement
# add note Lemelson–MIT Prize
# add note Rensselaer Polytechnic Institute
# add note Hofstra University
# add note 20 honorary doctorates*
# add relation Kurzweil Reading Machine*   Ray Kurzweil
# add relation Kurzweil Reading Machine*   Ray Kurzweil
# add relation Inventor of the Year*   Massachusetts Institute of Technology
# add relation Ray Kurzweil   Berklee College of Music
# add relation Dickson Prize   Massachusetts Institute of Technology
# add relation Ray Kurzweil   Dickson Prize
# add relation Ray Kurzweil   National Medal of Technology and Innovation
# add relation Academy of Achievement   Academy of Achievement
# add relation Ray Kurzweil   Lemelson–MIT Prize
# add relation Ray Kurzweil   Rensselaer Polytechnic Institute
# add relation Ray Kurzweil   Hofstra University
# add relation Ray Kurzweil   20 honorary doctorates*
# Knowledge graph saved at: separate_graph_folder/Raymond Kurzweil 10 NLP.html
# ==================================================
# Processing KB file: separate_kb_folder/Raymond Kurzweil 10.kb
# Generating knowledge graph for: Raymond Kurzweil 10.html
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# add note Kurzweil Reading Machine*
# add note Ray Kurzweil
# add note Inventor of the Year*
# add note Massachusetts Institute of Technology
# add note Berklee College of Music
# add note Dickson Prize
# add note National Medal of Technology and Innovation
# add note Academy of Achievement
# add note Lemelson–MIT Prize
# add note Rensselaer Polytechnic Institute
# add note Hofstra University
# add relation Kurzweil Reading Machine*   Ray Kurzweil
# add relation Kurzweil Reading Machine*   Ray Kurzweil
# add relation Inventor of the Year*   Massachusetts Institute of Technology
# add relation Ray Kurzweil   Berklee College of Music
# add relation Dickson Prize   Massachusetts Institute of Technology
# add relation Ray Kurzweil   Dickson Prize
# add relation Ray Kurzweil   National Medal of Technology and Innovation
# add relation Academy of Achievement   Academy of Achievement
# add relation Ray Kurzweil   Lemelson–MIT Prize
# add relation Ray Kurzweil   Rensselaer Polytechnic Institute
# add relation Ray Kurzweil   Hofstra University
# Knowledge graph saved at: separate_graph_folder/Raymond Kurzweil 10.html
# ==================================================
# Processing KB file: separate_kb_folder/Raymond Kurzweil 2 CoreNLP.kb
# Generating knowledge graph for: Raymond Kurzweil 2 CoreNLP.html
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# add note Queens
# add note New York City
# add note Kingsbury Elementary School*
# add note Kingsbury Elementary School PS188*
# add note NYC Public Education*
# add note Fredric*
# add note Pianist
# add note Ray Kurzweil
# add note Enid*
# add note Tom Swift Jr.
# add note Science fiction
# add note Tom Swift
# add note Transcendent Man
# add note 1960
# add note 1963
# add note Pattern recognition
# add note Computer science
# add note pattern-recognition software*
# add note I've Got a Secret
# add note CBS
# add note Lyndon B. Johnson
# add note President*
# add note White House
# add note first prize*
# add note International Science Fair*
# add relation Queens   New York City
# add relation New York City   Queens
# add relation Kingsbury Elementary School*   New York City
# add relation Kingsbury Elementary School PS188*   NYC Public Education*
# add relation Fredric*   Pianist
# add relation Ray Kurzweil   Fredric*
# add relation Ray Kurzweil   Enid*
# add relation Fredric*   Enid*
# add relation Enid*   Ray Kurzweil
# add relation Enid*   Fredric*
# add relation Tom Swift Jr.   Science fiction
# add relation Tom Swift   Science fiction
# add relation Transcendent Man   New York City
# add relation Transcendent Man   1960
# add relation Transcendent Man   Ray Kurzweil
# add relation Transcendent Man   1963
# add relation Pattern recognition   Computer science
# add relation pattern-recognition software*   Computer science
# add relation I've Got a Secret   CBS
# add relation Lyndon B. Johnson   President*
# add relation Lyndon B. Johnson   White House
# add relation first prize*   International Science Fair*
# Knowledge graph saved at: separate_graph_folder/Raymond Kurzweil 2 CoreNLP.html
# ==================================================
# Processing KB file: separate_kb_folder/Raymond Kurzweil 2.kb
# Generating knowledge graph for: Raymond Kurzweil 2.html
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# add note Queens
# add note New York City
# add note Kingsbury Elementary School*
# add note Kingsbury Elementary School PS188*
# add note NYC Public Education*
# add note Fredric*
# add note Pianist
# add note Ray Kurzweil
# add note Enid*
# add note Tom Swift Jr.
# add note Science fiction
# add note Tom Swift
# add note Transcendent Man
# add note 1960
# add note 1963
# add note Pattern recognition
# add note Computer science
# add note pattern-recognition software*
# add note I've Got a Secret
# add note CBS
# add note Lyndon B. Johnson
# add note President*
# add note White House
# add relation Queens   New York City
# add relation New York City   Queens
# add relation Kingsbury Elementary School*   New York City
# add relation Kingsbury Elementary School PS188*   NYC Public Education*
# add relation Fredric*   Pianist
# add relation Ray Kurzweil   Fredric*
# add relation Ray Kurzweil   Enid*
# add relation Fredric*   Enid*
# add relation Enid*   Ray Kurzweil
# add relation Enid*   Fredric*
# add relation Tom Swift Jr.   Science fiction
# add relation Tom Swift   Science fiction
# add relation Transcendent Man   New York City
# add relation Transcendent Man   1960
# add relation Transcendent Man   Ray Kurzweil
# add relation Transcendent Man   1963
# add relation Pattern recognition   Computer science
# add relation pattern-recognition software*   Computer science
# add relation I've Got a Secret   CBS
# add relation Lyndon B. Johnson   President*
# add relation Lyndon B. Johnson   White House
# Knowledge graph saved at: separate_graph_folder/Raymond Kurzweil 2.html
# ==================================================
# Processing KB file: separate_kb_folder/Raymond Kurzweil 3 CoreNLP.kb
# Generating knowledge graph for: Raymond Kurzweil 3 CoreNLP.html
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# add note Frank Rosenblatt
# add note Cornell University
# add note Marvin Minsky
# add note Massachusetts Institute of Technology
# add note Select College Consulting Program*
# add note 1968
# add note Ray Kurzweil
# add note Kurzweil Computer Products, Inc.*
# add note 1974
# add note Kurzweil Computer Products*
# add note 1978
# add note Kurzweil Reading Machine*
# add note January 13, 1976*
# add note Optical character recognition
# add note Nuance Communications
# add note Visioneer, Inc.*
# add note Kurzweil K250
# add note 1984
# add note Kurzweil Music Systems
# add note Young Chang
# add note South Korea
# add note Kurzweil Applied Intelligence*
# add note 1987
# add note Hyundai*
# add note Kurzweil Applied Intelligence (KAI)*
# add note KAI*
# add note 1997
# add relation Frank Rosenblatt   Cornell University
# add relation Frank Rosenblatt   Cornell University
# add relation Marvin Minsky   Massachusetts Institute of Technology
# add relation Select College Consulting Program*   1968
# add relation Select College Consulting Program*   Ray Kurzweil
# add relation Ray Kurzweil   Massachusetts Institute of Technology
# add relation Kurzweil Computer Products, Inc.*   1974
# add relation Kurzweil Computer Products, Inc.*   Ray Kurzweil
# add relation Kurzweil Computer Products*   1974
# add relation Kurzweil Computer Products*   1978
# add relation Kurzweil Reading Machine*   January 13, 1976*
# add relation Kurzweil Computer Products*   Optical character recognition
# add relation Kurzweil Computer Products*   Ray Kurzweil
# add relation Nuance Communications   Visioneer, Inc.*
# add relation Visioneer, Inc.*   Nuance Communications
# add relation Kurzweil K250   1984
# add relation Kurzweil K250   Kurzweil Music Systems
# add relation Young Chang   South Korea
# add relation Kurzweil Music Systems   Young Chang
# add relation Young Chang   Kurzweil Music Systems
# add relation Kurzweil Applied Intelligence*   1987
# add relation Young Chang   Hyundai*
# add relation Kurzweil Applied Intelligence (KAI)*   1987
# add relation KAI*   1997
# Knowledge graph saved at: separate_graph_folder/Raymond Kurzweil 3 CoreNLP.html
# ==================================================
# Processing KB file: separate_kb_folder/Raymond Kurzweil 3.kb
# Generating knowledge graph for: Raymond Kurzweil 3.html
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# add note Frank Rosenblatt
# add note Cornell University
# add note Marvin Minsky
# add note Massachusetts Institute of Technology
# add note Select College Consulting Program*
# add note 1968
# add note Ray Kurzweil
# add note Kurzweil Computer Products, Inc.*
# add note 1974
# add note Kurzweil Computer Products*
# add note 1978
# add note Kurzweil Reading Machine*
# add note January 13, 1976*
# add note Optical character recognition
# add note Nuance Communications
# add note Visioneer, Inc.*
# add note Kurzweil K250
# add note 1984
# add note Kurzweil Music Systems
# add note Young Chang
# add note South Korea
# add note Kurzweil Applied Intelligence*
# add note 1987
# add note Hyundai*
# add note Kurzweil Applied Intelligence (KAI)*
# add relation Frank Rosenblatt   Cornell University
# add relation Frank Rosenblatt   Cornell University
# add relation Marvin Minsky   Massachusetts Institute of Technology
# add relation Select College Consulting Program*   1968
# add relation Select College Consulting Program*   Ray Kurzweil
# add relation Ray Kurzweil   Massachusetts Institute of Technology
# add relation Kurzweil Computer Products, Inc.*   1974
# add relation Kurzweil Computer Products, Inc.*   Ray Kurzweil
# add relation Kurzweil Computer Products*   1974
# add relation Kurzweil Computer Products*   1978
# add relation Kurzweil Reading Machine*   January 13, 1976*
# add relation Kurzweil Computer Products*   Optical character recognition
# add relation Kurzweil Computer Products*   Ray Kurzweil
# add relation Nuance Communications   Visioneer, Inc.*
# add relation Visioneer, Inc.*   Nuance Communications
# add relation Kurzweil K250   1984
# add relation Kurzweil K250   Kurzweil Music Systems
# add relation Young Chang   South Korea
# add relation Kurzweil Music Systems   Young Chang
# add relation Young Chang   Kurzweil Music Systems
# add relation Kurzweil Applied Intelligence*   1987
# add relation Young Chang   Hyundai*
# add relation Kurzweil Applied Intelligence (KAI)*   1987
# Knowledge graph saved at: separate_graph_folder/Raymond Kurzweil 3.html
# ==================================================
# Processing KB file: separate_kb_folder/Raymond Kurzweil 4 CoreNLP.kb
# Generating knowledge graph for: Raymond Kurzweil 4 CoreNLP.html
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# add note Kurzweil Educational Systems
# add note 1996
# add note Ray Kurzweil
# add note Dyslexia
# add note Disability
# add note Medical Learning Company*
# add note 1999
# add note 1990
# add note The Age of Spiritual Machines
# add note Google
# add note Larry Page
# add note Natural language
# add relation Kurzweil Educational Systems   1996
# add relation Kurzweil Educational Systems   Ray Kurzweil
# add relation Dyslexia   Disability
# add relation Medical Learning Company*   1999
# add relation Medical Learning Company*   1990
# add relation Kurzweil Educational Systems   1999
# add relation The Age of Spiritual Machines   1999
# add relation The Age of Spiritual Machines   Ray Kurzweil
# add relation Google   Larry Page
# add relation Larry Page   Google
# add relation Natural language   Google
# Knowledge graph saved at: separate_graph_folder/Raymond Kurzweil 4 CoreNLP.html
# ==================================================
# Processing KB file: separate_kb_folder/Raymond Kurzweil 4.kb
# Generating knowledge graph for: Raymond Kurzweil 4.html
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# add note Kurzweil Educational Systems
# add note 1996
# add note Ray Kurzweil
# add note Dyslexia
# add note Disability
# add note Medical Learning Company*
# add note 1999
# add note 1990
# add note The Age of Spiritual Machines
# add note Google
# add note Larry Page
# add relation Kurzweil Educational Systems   1996
# add relation Kurzweil Educational Systems   Ray Kurzweil
# add relation Dyslexia   Disability
# add relation Medical Learning Company*   1999
# add relation Medical Learning Company*   1990
# add relation Kurzweil Educational Systems   1999
# add relation The Age of Spiritual Machines   1999
# add relation The Age of Spiritual Machines   Ray Kurzweil
# add relation Google   Larry Page
# add relation Larry Page   Google
# Knowledge graph saved at: separate_graph_folder/Raymond Kurzweil 4.html
# ==================================================
# Processing KB file: separate_kb_folder/Raymond Kurzweil 5 CoreNLP.kb
# Generating knowledge graph for: Raymond Kurzweil 5 CoreNLP.html
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# add note Sonya Rosenwald Kurzweil*
# add note Harvard Medical School
# add note Ray Kurzweil
# add note William James College for Graduate Education in Psychology*
# add note Ethan Kurzweil*
# add note Amy Kurzweil
# add note Venture capital
# add note Lucid dream
# add note awakening*
# add note lucid dreamlike state*
# add note awakening state*
# add note Raymond Kurzweil’s awakening state*
# add note Invention
# add relation Sonya Rosenwald Kurzweil*   Harvard Medical School
# add relation Ray Kurzweil   Sonya Rosenwald Kurzweil*
# add relation Sonya Rosenwald Kurzweil*   Ray Kurzweil
# add relation Sonya Rosenwald Kurzweil*   Harvard Medical School
# add relation Sonya Rosenwald Kurzweil*   William James College for Graduate Education in Psychology*
# add relation Ethan Kurzweil*   Amy Kurzweil
# add relation Amy Kurzweil   Ethan Kurzweil*
# add relation Ethan Kurzweil*   Ray Kurzweil
# add relation Ethan Kurzweil*   Venture capital
# add relation Lucid dream   awakening*
# add relation awakening*   Lucid dream
# add relation lucid dreamlike state*   awakening state*
# add relation awakening state*   lucid dreamlike state*
# add relation Raymond Kurzweil’s awakening state*   Lucid dream
# add relation Ray Kurzweil   Invention
# Knowledge graph saved at: separate_graph_folder/Raymond Kurzweil 5 CoreNLP.html
# ==================================================
# Processing KB file: separate_kb_folder/Raymond Kurzweil 5.kb
# Generating knowledge graph for: Raymond Kurzweil 5.html
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# add note Sonya Rosenwald Kurzweil*
# add note Harvard Medical School
# add note Ray Kurzweil
# add note William James College for Graduate Education in Psychology*
# add note Ethan Kurzweil*
# add note Amy Kurzweil
# add note Venture capital
# add note Lucid dream
# add note awakening*
# add note lucid dreamlike state*
# add note awakening state*
# add note Raymond Kurzweil’s awakening state*
# add relation Sonya Rosenwald Kurzweil*   Harvard Medical School
# add relation Ray Kurzweil   Sonya Rosenwald Kurzweil*
# add relation Sonya Rosenwald Kurzweil*   Ray Kurzweil
# add relation Sonya Rosenwald Kurzweil*   Harvard Medical School
# add relation Sonya Rosenwald Kurzweil*   William James College for Graduate Education in Psychology*
# add relation Ethan Kurzweil*   Amy Kurzweil
# add relation Amy Kurzweil   Ethan Kurzweil*
# add relation Ethan Kurzweil*   Ray Kurzweil
# add relation Ethan Kurzweil*   Venture capital
# add relation Lucid dream   awakening*
# add relation awakening*   Lucid dream
# add relation lucid dreamlike state*   awakening state*
# add relation awakening state*   lucid dreamlike state*
# add relation Raymond Kurzweil’s awakening state*   Lucid dream
# Knowledge graph saved at: separate_graph_folder/Raymond Kurzweil 5.html
# ==================================================
# Processing KB file: separate_kb_folder/Raymond Kurzweil 6 CoreNLP.kb
# Generating knowledge graph for: Raymond Kurzweil 6 CoreNLP.html
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# add note The Age of Intelligent Machines
# add note 1990
# add note The 10% Solution for a Healthy Life
# add note 1993
# add note The Age of Spiritual Machines
# add note 1999
# add note Ray Kurzweil
# add note Film
# add note Pauley Perrette
# add note NCIS*
# add note The Singularity Is Near
# add note 2005
# add note Transcendent Man
# add note Barry Ptolemy
# add note How to Create a Mind
# add note November 13, 2012*
# add note Fantastic Voyage
# add note Danielle: Chronicles of a Superheroine*
# add note Superintelligence
# add note 2024
# add note 2010
# add note Anthony Waller
# add note Plug & Pray
# add note Joseph Weizenbaum
# add note 2012
# add note large-scale achievement*
# add note its documentation of futurist*
# add relation The Age of Intelligent Machines   1990
# add relation The 10% Solution for a Healthy Life   1993
# add relation The Age of Spiritual Machines   1999
# add relation The Age of Spiritual Machines   Ray Kurzweil
# add relation Film   Pauley Perrette
# add relation NCIS*   Pauley Perrette
# add relation The Singularity Is Near   2005
# add relation Film   The Singularity Is Near
# add relation Transcendent Man   Barry Ptolemy
# add relation How to Create a Mind   November 13, 2012*
# add relation Fantastic Voyage   Barry Ptolemy
# add relation Danielle: Chronicles of a Superheroine*   Ray Kurzweil
# add relation Ray Kurzweil   Danielle: Chronicles of a Superheroine*
# add relation Ray Kurzweil   Superintelligence
# add relation Ray Kurzweil   2024
# add relation Ray Kurzweil   2010
# add relation Ray Kurzweil   Anthony Waller
# add relation The Singularity Is Near   2010
# add relation The Singularity Is Near   Anthony Waller
# add relation Transcendent Man   2010
# add relation Plug & Pray   Joseph Weizenbaum
# add relation Plug & Pray   2012
# add relation Plug & Pray   Ray Kurzweil
# add relation large-scale achievement*   its documentation of futurist*
# Knowledge graph saved at: separate_graph_folder/Raymond Kurzweil 6 CoreNLP.html
# ==================================================
# Processing KB file: separate_kb_folder/Raymond Kurzweil 6.kb
# Generating knowledge graph for: Raymond Kurzweil 6.html
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# add note The Age of Intelligent Machines
# add note 1990
# add note The 10% Solution for a Healthy Life
# add note 1993
# add note The Age of Spiritual Machines
# add note 1999
# add note Ray Kurzweil
# add note Film
# add note Pauley Perrette
# add note NCIS*
# add note The Singularity Is Near
# add note 2005
# add note Transcendent Man
# add note Barry Ptolemy
# add note How to Create a Mind
# add note November 13, 2012*
# add note Fantastic Voyage
# add note Danielle: Chronicles of a Superheroine*
# add note Superintelligence
# add note 2024
# add note 2010
# add note Anthony Waller
# add note Plug & Pray
# add note Joseph Weizenbaum
# add note 2012
# add relation The Age of Intelligent Machines   1990
# add relation The 10% Solution for a Healthy Life   1993
# add relation The Age of Spiritual Machines   1999
# add relation The Age of Spiritual Machines   Ray Kurzweil
# add relation Film   Pauley Perrette
# add relation NCIS*   Pauley Perrette
# add relation The Singularity Is Near   2005
# add relation Film   The Singularity Is Near
# add relation Transcendent Man   Barry Ptolemy
# add relation How to Create a Mind   November 13, 2012*
# add relation Fantastic Voyage   Barry Ptolemy
# add relation Danielle: Chronicles of a Superheroine*   Ray Kurzweil
# add relation Ray Kurzweil   Danielle: Chronicles of a Superheroine*
# add relation Ray Kurzweil   Superintelligence
# add relation Ray Kurzweil   2024
# add relation Ray Kurzweil   2010
# add relation Ray Kurzweil   Anthony Waller
# add relation The Singularity Is Near   2010
# add relation The Singularity Is Near   Anthony Waller
# add relation Transcendent Man   2010
# add relation Plug & Pray   Joseph Weizenbaum
# add relation Plug & Pray   2012
# add relation Plug & Pray   Ray Kurzweil
# Knowledge graph saved at: separate_graph_folder/Raymond Kurzweil 6.html
# ==================================================
# Processing KB file: separate_kb_folder/Raymond Kurzweil 7 CoreNLP.kb
# Generating knowledge graph for: Raymond Kurzweil 7 CoreNLP.html
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# add note The Age of Spiritual Machines
# add note 1999
# add note Ray Kurzweil
# add note Technological singularity
# add note John A. Neumann*
# add note Nanotechnology
# add note Biotechnology
# add note John von Neumann
# add note Nanotech Could Give Global Warming a Big Chill*
# add note software viruses*
# add note Computer
# add note biological pathogens*
# add note Evolution
# add note defense*
# add note Technology
# add note Type 2 diabetes
# add note Cardiovascular disease
# add note Prediabetes
# add note Red wine
# add note Biochemistry
# add note Water ionizer
# add note supplements*
# add note Transhumanism
# add note Futurism
# add note Stanford University
# add note Palo Alto, California
# add note Singularity Group
# add note Google
# add note self-described mission*
# add relation The Age of Spiritual Machines   1999
# add relation The Age of Spiritual Machines   Ray Kurzweil
# add relation Technological singularity   John A. Neumann*
# add relation Nanotechnology   Biotechnology
# add relation Technological singularity   John von Neumann
# add relation Nanotech Could Give Global Warming a Big Chill*   Ray Kurzweil
# add relation software viruses*   Computer
# add relation biological pathogens*   Evolution
# add relation biological pathogens*   Evolution
# add relation defense*   Technology
# add relation Type 2 diabetes   Cardiovascular disease
# add relation Prediabetes   Type 2 diabetes
# add relation Red wine   Biochemistry
# add relation Biochemistry   Red wine
# add relation Water ionizer   supplements*
# add relation Transhumanism   Futurism
# add relation Transhumanism   Futurism
# add relation Transhumanism   Futurism
# add relation Stanford University   Palo Alto, California
# add relation Stanford University   Palo Alto, California
# add relation Ray Kurzweil   Stanford University
# add relation Singularity Group   Ray Kurzweil
# add relation Google   Singularity Group
# add relation Singularity Group   self-described mission*
# Knowledge graph saved at: separate_graph_folder/Raymond Kurzweil 7 CoreNLP.html
# ==================================================
# Processing KB file: separate_kb_folder/Raymond Kurzweil 7.kb
# Generating knowledge graph for: Raymond Kurzweil 7.html
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# add note The Age of Spiritual Machines
# add note 1999
# add note Ray Kurzweil
# add note Technological singularity
# add note John A. Neumann*
# add note Nanotechnology
# add note Biotechnology
# add note John von Neumann
# add note Nanotech Could Give Global Warming a Big Chill*
# add note software viruses*
# add note Computer
# add note biological pathogens*
# add note Evolution
# add note defense*
# add note Technology
# add note Type 2 diabetes
# add note Cardiovascular disease
# add note Prediabetes
# add note Red wine
# add note Biochemistry
# add note Water ionizer
# add note supplements*
# add note Transhumanism
# add note Futurism
# add note Stanford University
# add note Palo Alto, California
# add note Singularity Group
# add note Google
# add relation The Age of Spiritual Machines   1999
# add relation The Age of Spiritual Machines   Ray Kurzweil
# add relation Technological singularity   John A. Neumann*
# add relation Nanotechnology   Biotechnology
# add relation Technological singularity   John von Neumann
# add relation Nanotech Could Give Global Warming a Big Chill*   Ray Kurzweil
# add relation software viruses*   Computer
# add relation biological pathogens*   Evolution
# add relation biological pathogens*   Evolution
# add relation defense*   Technology
# add relation Type 2 diabetes   Cardiovascular disease
# add relation Prediabetes   Type 2 diabetes
# add relation Red wine   Biochemistry
# add relation Biochemistry   Red wine
# add relation Water ionizer   supplements*
# add relation Transhumanism   Futurism
# add relation Transhumanism   Futurism
# add relation Transhumanism   Futurism
# add relation Stanford University   Palo Alto, California
# add relation Stanford University   Palo Alto, California
# add relation Ray Kurzweil   Stanford University
# add relation Singularity Group   Ray Kurzweil
# add relation Google   Singularity Group
# Knowledge graph saved at: separate_graph_folder/Raymond Kurzweil 7.html
# ==================================================
# Processing KB file: separate_kb_folder/Raymond Kurzweil 8 CoreNLP.kb
# Generating knowledge graph for: Raymond Kurzweil 8 CoreNLP.html
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# add note The Age of Intelligent Machines
# add note 1990
# add note Ithiel de Sola Pool
# add note Deep Blue*
# add note IBM
# add note Ray Kurzweil
# add note 2010
# add note The Age of Spiritual Machines
# add note The Singularity Is Near
# add note Raymond Kurzwe*
# add note How My Predictions Are Faring*
# add note Raymond Kur*
# add note Daniel Lyons
# add note Newsweek
# add note 1998 dot-com*
# add note 1998
# add note Google
# add note Speech recognition
# add note recognition*
# add note Supercomputer
# add note 1999
# add note Turing test
# add note Human
# add note Nanorobotics
# add note Cognitive skill
# add note Transcendent Man
# add note Sun
# add note Earth
# add note Rosso-Ukrainian War*
# add note nuclear armaggedon*
# add note nuclear war is unlikely*
# add note Nuclear warfare
# add note Nuclear war is a possibility but nuclear war is unlikely*
# add note worries about technology*
# add relation The Age of Intelligent Machines   1990
# add relation Ithiel de Sola Pool   Ithiel de Sola Pool
# add relation Deep Blue*   IBM
# add relation The Age of Intelligent Machines   Ray Kurzweil
# add relation Ray Kurzweil   2010
# add relation Ray Kurzweil   Ray Kurzweil
# add relation The Age of Intelligent Machines   The Age of Spiritual Machines
# add relation The Age of Spiritual Machines   The Singularity Is Near
# add relation The Age of Spiritual Machines   Ray Kurzweil
# add relation The Singularity Is Near   Ray Kurzweil
# add relation The Singularity Is Near   Raymond Kurzwe*
# add relation How My Predictions Are Faring*   Ray Kurzweil
# add relation The Age of Spiritual Machines   Raymond Kur*
# add relation Daniel Lyons   Newsweek
# add relation 1998 dot-com*   1998
# add relation Newsweek   Daniel Lyons
# add relation Google   Google
# add relation Speech recognition   recognition*
# add relation Google   Supercomputer
# add relation The Age of Spiritual Machines   1999
# add relation Turing test   Human
# add relation Nanorobotics   Nanorobotics
# add relation Turing test   Cognitive skill
# add relation Transcendent Man   Ray Kurzweil
# add relation Sun   Earth
# add relation Earth   Sun
# add relation Rosso-Ukrainian War*   nuclear armaggedon*
# add relation nuclear war is unlikely*   Nuclear warfare
# add relation nuclear war is unlikely*   Nuclear warfare
# add relation Nuclear war is a possibility but nuclear war is unlikely*   Nuclear warfare
# add relation Ray Kurzweil   worries about technology*
# Knowledge graph saved at: separate_graph_folder/Raymond Kurzweil 8 CoreNLP.html
# ==================================================
# Processing KB file: separate_kb_folder/Raymond Kurzweil 8.kb
# Generating knowledge graph for: Raymond Kurzweil 8.html
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# add note The Age of Intelligent Machines
# add note 1990
# add note Ithiel de Sola Pool
# add note Deep Blue*
# add note IBM
# add note Ray Kurzweil
# add note 2010
# add note The Age of Spiritual Machines
# add note The Singularity Is Near
# add note Raymond Kurzwe*
# add note How My Predictions Are Faring*
# add note Raymond Kur*
# add note Daniel Lyons
# add note Newsweek
# add note 1998 dot-com*
# add note 1998
# add note Google
# add note Speech recognition
# add note recognition*
# add note Supercomputer
# add note 1999
# add note Turing test
# add note Human
# add note Nanorobotics
# add note Cognitive skill
# add note Transcendent Man
# add note Sun
# add note Earth
# add note Rosso-Ukrainian War*
# add note nuclear armaggedon*
# add note nuclear war is unlikely*
# add note Nuclear warfare
# add note Nuclear war is a possibility but nuclear war is unlikely*
# add relation The Age of Intelligent Machines   1990
# add relation Ithiel de Sola Pool   Ithiel de Sola Pool
# add relation Deep Blue*   IBM
# add relation The Age of Intelligent Machines   Ray Kurzweil
# add relation Ray Kurzweil   2010
# add relation Ray Kurzweil   Ray Kurzweil
# add relation The Age of Intelligent Machines   The Age of Spiritual Machines
# add relation The Age of Spiritual Machines   The Singularity Is Near
# add relation The Age of Spiritual Machines   Ray Kurzweil
# add relation The Singularity Is Near   Ray Kurzweil
# add relation The Singularity Is Near   Raymond Kurzwe*
# add relation How My Predictions Are Faring*   Ray Kurzweil
# add relation The Age of Spiritual Machines   Raymond Kur*
# add relation Daniel Lyons   Newsweek
# add relation 1998 dot-com*   1998
# add relation Newsweek   Daniel Lyons
# add relation Google   Google
# add relation Speech recognition   recognition*
# add relation Google   Supercomputer
# add relation The Age of Spiritual Machines   1999
# add relation Turing test   Human
# add relation Nanorobotics   Nanorobotics
# add relation Turing test   Cognitive skill
# add relation Transcendent Man   Ray Kurzweil
# add relation Sun   Earth
# add relation Earth   Sun
# add relation Rosso-Ukrainian War*   nuclear armaggedon*
# add relation nuclear war is unlikely*   Nuclear warfare
# add relation nuclear war is unlikely*   Nuclear warfare
# add relation Nuclear war is a possibility but nuclear war is unlikely*   Nuclear warfare
# Knowledge graph saved at: separate_graph_folder/Raymond Kurzweil 8.html
# ==================================================
# Processing KB file: separate_kb_folder/Raymond Kurzweil 9 CoreNLP.kb
# Generating knowledge graph for: Raymond Kurzweil 9 CoreNLP.html
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# add note Bill Gates
# add note Forbes
# add note The Wall Street Journal
# add note Neal Stephenson
# add note Science fiction
# add note Ray Kurzweil
# add note Daniel Dennett
# add note Artificial intelligence
# add note Rodney Brooks
# add note David Gelernter
# add note Paul Allen
# add note John Rennie*
# add note IEEE Spectrum
# add note Sun Microsystems
# add note Bill Joy
# add note Lotus Software
# add note Mitch Kapor
# add note Douglas Hofstadter
# add note Cognitive science
# add note Hans Moravec
# add note Theodore Modis
# add note Futurist
# add note One Half of a Manifesto*
# add note Jaron Lanier
# add note Singularity*
# add note William Nordhaus
# add note Yale University
# add note required steep rises*
# add note Information technology
# add relation Bill Gates   Forbes
# add relation Bill Gates   The Wall Street Journal
# add relation Forbes   The Wall Street Journal
# add relation Neal Stephenson   Science fiction
# add relation Ray Kurzweil   Science fiction
# add relation Daniel Dennett   Artificial intelligence
# add relation Rodney Brooks   Artificial intelligence
# add relation David Gelernter   Artificial intelligence
# add relation Paul Allen   Artificial intelligence
# add relation John Rennie*   IEEE Spectrum
# add relation IEEE Spectrum   John Rennie*
# add relation Sun Microsystems   Bill Joy
# add relation Lotus Software   Mitch Kapor
# add relation Bill Joy   Sun Microsystems
# add relation Douglas Hofstadter   Cognitive science
# add relation Hans Moravec   Cognitive science
# add relation Douglas Hofstadter   Cognitive science
# add relation Theodore Modis   Futurist
# add relation One Half of a Manifesto*   Jaron Lanier
# add relation Theodore Modis   Futurist
# add relation Singularity*   Ray Kurzweil
# add relation Singularity*   Ray Kurzweil
# add relation Singularity*   Ray Kurzweil
# add relation William Nordhaus   Yale University
# add relation William Nordhaus   Yale University
# add relation Ray Kurzweil   Yale University
# add relation required steep rises*   Information technology
# Knowledge graph saved at: separate_graph_folder/Raymond Kurzweil 9 CoreNLP.html
# ==================================================
# Processing KB file: separate_kb_folder/Raymond Kurzweil 9.kb
# Generating knowledge graph for: Raymond Kurzweil 9.html
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# add note Bill Gates
# add note Forbes
# add note The Wall Street Journal
# add note Neal Stephenson
# add note Science fiction
# add note Ray Kurzweil
# add note Daniel Dennett
# add note Artificial intelligence
# add note Rodney Brooks
# add note David Gelernter
# add note Paul Allen
# add note John Rennie*
# add note IEEE Spectrum
# add note Sun Microsystems
# add note Bill Joy
# add note Lotus Software
# add note Mitch Kapor
# add note Douglas Hofstadter
# add note Cognitive science
# add note Hans Moravec
# add note Theodore Modis
# add note Futurist
# add note One Half of a Manifesto*
# add note Jaron Lanier
# add note Singularity*
# add note William Nordhaus
# add note Yale University
# add relation Bill Gates   Forbes
# add relation Bill Gates   The Wall Street Journal
# add relation Forbes   The Wall Street Journal
# add relation Neal Stephenson   Science fiction
# add relation Ray Kurzweil   Science fiction
# add relation Daniel Dennett   Artificial intelligence
# add relation Rodney Brooks   Artificial intelligence
# add relation David Gelernter   Artificial intelligence
# add relation Paul Allen   Artificial intelligence
# add relation John Rennie*   IEEE Spectrum
# add relation IEEE Spectrum   John Rennie*
# add relation Sun Microsystems   Bill Joy
# add relation Lotus Software   Mitch Kapor
# add relation Bill Joy   Sun Microsystems
# add relation Douglas Hofstadter   Cognitive science
# add relation Hans Moravec   Cognitive science
# add relation Douglas Hofstadter   Cognitive science
# add relation Theodore Modis   Futurist
# add relation One Half of a Manifesto*   Jaron Lanier
# add relation Theodore Modis   Futurist
# add relation Singularity*   Ray Kurzweil
# add relation Singularity*   Ray Kurzweil
# add relation Singularity*   Ray Kurzweil
# add relation William Nordhaus   Yale University
# add relation William Nordhaus   Yale University
# add relation Ray Kurzweil   Yale University
# Knowledge graph saved at: separate_graph_folder/Raymond Kurzweil 9.html
# ==================================================
# Processing KB file: separate_kb_folder/Raymond Kurzweil Complete.kb
# Generating knowledge graph for: Raymond Kurzweil Complete.html
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# add note Kurzweil Reading Machine*
# add note Ray Kurzweil
# add note Inventor of the Year*
# add note Massachusetts Institute of Technology
# add note Berklee College of Music
# add note Dickson Prize
# add note National Medal of Technology and Innovation
# add note Dickson Prize in Science*
# add note Academy of Achievement
# add note National Medal of Technology*
# add note Raymond Kurzweil*
# add note Lemelson–MIT Prize
# add note Rensselaer Polytechnic Institute
# add note Hofstra University
# add relation Kurzweil Reading Machine*   Ray Kurzweil
# add relation Kurzweil Reading Machine*   Ray Kurzweil
# add relation Inventor of the Year*   Massachusetts Institute of Technology
# add relation Ray Kurzweil   Berklee College of Music
# add relation Dickson Prize   Massachusetts Institute of Technology
# add relation Ray Kurzweil   Dickson Prize
# add relation Ray Kurzweil   National Medal of Technology and Innovation
# add relation Ray Kurzweil   Dickson Prize in Science*
# add relation Academy of Achievement   Academy of Achievement
# add relation Ray Kurzweil   National Medal of Technology*
# add relation Raymond Kurzweil*   National Medal of Technology*
# add relation Ray Kurzweil   Lemelson–MIT Prize
# add relation Kurzweil Reading Machine*   Raymond Kurzweil*
# add relation Ray Kurzweil   Rensselaer Polytechnic Institute
# add relation Ray Kurzweil   Hofstra University
# add relation Raymond Kurzweil*   Hofstra University
# Knowledge graph saved at: separate_graph_folder/Raymond Kurzweil Complete.html
# ==================================================
# Processing KB file: separate_kb_folder/Try.kb
# Generating knowledge graph for: Try.html
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# add note Thomas Edison
# add note rightful heir*
# add relation Thomas Edison   rightful heir*
# Knowledge graph saved at: separate_graph_folder/Try.html
# ==================================================
